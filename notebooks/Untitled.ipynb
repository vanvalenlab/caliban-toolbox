# %%
import os
os.listdir("/data/data/cells/HeLa/S3/set2/raw")
# Out:
# ['img_000000040_Phase_001.png',
#  'img_000000020_Far-red_001.png',
#  'img_000000019_Phase_002.png',
#  'img_000000007_Phase_001.png',
#  'img_000000003_Phase_000.png',
#  'img_000000010_Phase_002.png',
#  'img_000000028_Phase_001.png',
#  'img_000000044_Phase_000.png',
#  'img_000000041_Phase_001.png',
#  'img_000000029_Far-red_001.png',
#  'img_000000044_Phase_002.png',
#  'img_000000035_Phase_002.png',
#  'img_000000036_FITC_001.png',
#  'img_000000030_Far-red_001.png',
#  'img_000000017_FITC_001.png',
#  'img_000000030_FITC_001.png',
#  'img_000000035_FITC_001.png',
#  'img_000000043_FITC_001.png',
#  'img_000000010_Far-red_001.png',
#  'img_000000013_Far-red_001.png',
#  'img_000000008_Phase_000.png',
#  'img_000000042_FITC_001.png',
#  'img_000000044_FITC_001.png',
#  'img_000000043_Phase_000.png',
#  'img_000000041_Far-red_001.png',
#  'img_000000027_Phase_001.png',
#  'img_000000036_Phase_000.png',
#  'img_000000008_Far-red_001.png',
#  'img_000000029_FITC_001.png',
# ...

# %%
from shutil import copy2

copy2("/data/data/cells/HeLa/S3/set1/raw/img_000000041_Phase_000.png", "temp")
# Out:
# 'temp/img_000000041_Phase_000.png'
